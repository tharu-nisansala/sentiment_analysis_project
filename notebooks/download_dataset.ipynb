# %%
import json
with open('../artifacts/kaggle.json','r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'tharushinisansala', 'key': '76bf5395210b20afff761c210e11a261'}

# %%
# %pip install Kaggle
# Out:
# Collecting Kaggle
#   Downloading kaggle-2.0.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from Kaggle) (6.3.0)
# Collecting kagglesdk<1.0,>=0.1.17 (from Kaggle)
#   Downloading kagglesdk-0.1.19-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from Kaggle) (26.1)
# Collecting protobuf (from Kaggle)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: python-dateutil in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from Kaggle) (2.9.0.post0)
# Collecting python-slugify (from Kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from Kaggle) (2.33.1)
# Collecting tqdm (from Kaggle)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from Kaggle) (2.6.3)
# Requirement already satisfied: webencodings in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from bleach->Kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from python-dateutil->Kaggle) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify->Kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from requests->Kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from requests->Kaggle) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from requests->Kaggle) (2026.2.25)
# Requirement already satisfied: colorama in c:\Users\Acer\Desktop\sentiment_analysis_project\venv\Lib\site-packages (from tqdm->Kaggle) (0.4.6)
# Downloading kaggle-2.0.1-py3-none-any.whl (76 kB)
# Downloading kagglesdk-0.1.19-py3-none-any.whl (208 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kagglesdk, Kaggle
#
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------------- -------------------------- 2/6 [python-slugify]
#    ------------- -------------------------- 2/6 [python-slugify]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    --------------------------------- ------ 5/6 [Kaggle]
#    --------------------------------- ------ 5/6 [Kaggle]
#    --------------------------------- ------ 5/6 [Kaggle]
#    --------------------------------- ------ 5/6 [Kaggle]
#    ---------------------------------------- 6/6 [Kaggle]
#
# Successfully installed Kaggle-2.0.1 kagglesdk-0.1.19 protobuf-7.34.1 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset
